# %% [markdown]
# ### KINGSLEY AMADI-BENNETT
# ### CWID: 50262316
# ### ASSIGNMENT 2

# %% [markdown]
# #### Q1: Pseudocode
#
# - Initialize the variables for streaks, counting_var, checking_var, current_var.
# - Open up a for loop to generate random values for H or T.
#     - for i in range(10000):
#     -    flip = random.randint(0, 1)
#     -    if flip == 0:
#     -        headsOrTails.append("H")
#     -    elif flip == 1:
#     -        headsOrTails.append("T")
# - Open up a for loop to check for streaks and save the total number of streaks
#     - for c in range(len(headsOrTails)):
#     -   current_var = checking_var
#     -   checking_var = headsOrTails[c]
#     -   if current_var == checking_var:
#     -       counting_var += 1
#     -   elif current_var != checking_var:
#     -       counting_var = 0
#     -   if counting_var == 5:
#     -       streaks += 1
# - Print number of winning streaks

# %%
#Question 1

import random

streaks = 0
counting_var = 0
checking_var = 0 #Holds the previously checked list index
current_var = 0 #Holds current list index

headsOrTails = []

for i in range(10000):
        flip = random.randint(0,1)
        if flip == 0:
            headsOrTails.append("H")
        elif flip == 1:
            headsOrTails.append("T")
    # Check if there is a streak of 5 and store the number of streaks
for s in range(len(headsOrTails)):
        current_var = checking_var
        checking_var = headsOrTails[s]
        if current_var == checking_var:
            counting_var += 1
        elif current_var != checking_var:
            counting_var = 0
        if counting_var == 5:
            streaks += 1
    
streaks = str(streaks)
print('Number of streaks: ' + streaks)
# Out:
# Number of streaks: 169

# %% [markdown]
# #### Q2: Pseudocode
# - Collect User name
#     - name = input()
# - Collect values for number of swords, diamonds, gold coins, ropes and potions
#     - swords = input()
#     - diamonds = input()
#     - coins = input()
#     - ropes = input()
#     - potions = input()
# - Create a dict
#     - dict = {'Swords': swords, 'Diamonds': diamonds, 'Coins': coins, 'Ropes': ropes, 'Potions': potions}
# - Print out the contents of the dictionary
#     - print(dict['Swords'], "swords")
#     - print(dict['Diamonds'], "diamonds")
#     - print(dict['Coins'], "coins")
#     - print(dict['Ropes'], "ropes")
#     - print(dict['Potions'], "potions")

# %%
#Question 2 Solution
print("Hi, Please input your name")
name = input()
print("Welcome " + name)
print("Please input the value of the NUMBER OF SWORDS")
swords = input()
print("Please input the value of the NUMBER OF DIAMONDS")
diamonds = input()
print("Please input the value of the NUMBER OF GOLD COINS")
coins = input()
print("Please input the value of the NUMBER OF ROPES")
ropes = input()
print("Please input the value of the NUMBER OF POTIONS")
potions = input()

dict = {'Swords': swords, 'Diamonds': diamonds, 'Coins': coins, 'Ropes': ropes, 'Potions': potions}
print("Thanks for your input. The below is the inventory.")
print("Inventory: ")
print(dict['Swords'], "swords")
print(dict['Diamonds'], "diamonds")
print(dict['Coins'], "gold coins")
print(dict['Ropes'], "ropes")
print(dict['Potions'], "potions")
# Out:
# Hi, Please input your name
# K
# Welcome K
# Please input the value of the NUMBER OF SWORDS
# 5
# Please input the value of the NUMBER OF DIAMONDS
# 7
# Please input the value of the NUMBER OF GOLD COINS
# 7
# Please input the value of the NUMBER OF ROPES
# 9
# Please input the value of the NUMBER OF POTIONS
# 0
# Thanks for your input. The below is the inventory.
# Inventory:
# 5 swords
# 7 diamonds
# 7 gold coins
# 9 ropes
# 0 potions

# %% [markdown]
# #### Q3: Pseudocode
#
# - Initialize the variables for streaks, counting_var, checking_var, current_var.
# - Open up a for loop to generate random values for H or T.
#     - for i in range(10000):
#     -    flip = random.randint(0, 1)
#     -    if flip == 0:
#     -        headsOrTails.append("H")
#     -    elif flip == 1:
#     -        headsOrTails.append("T")
# - Convert generated list to an array
#     - hot_array = np.array(headsOrTails) #convert list to array
# - Open up a for loop to check for streaks and save the total number of streaks
#     - for c in range(len(hot_array)):
#     -   current_var = checking_var
#     -   checking_var = hot_array[c]
#     -   if current_var == checking_var:
#     -       counting_var += 1
#     -   elif current_var != checking_var:
#     -       counting_var = 0
#     -   if counting_var == 5:
#     -       streaks += 1
# - Print number of winning streaks

# %%
#Question 3 solution:

import numpy as np
import random

streaks = 0
counting_var = 0
checking_var = 0 #Holds the previously checked list index
current_var = 0 #Holds current list index

headsOrTails = []

for i in range(10000):
        flip = random.randint(0,1)
        if flip == 0:
            headsOrTails.append("H")
        elif flip == 1:
            headsOrTails.append("T")

# streak checker
headsOrTails_array = np.array(headsOrTails) #convert list to array
for s in range(len(headsOrTails_array)):
        current_var = checking_var
        checking_var = headsOrTails_array[s]
        if current_var == checking_var:
            counting_var += 1
        elif current_var != checking_var:
            counting_var = 0
        if counting_var == 5:
            streaks += 1
            
print(type(headsOrTails_array)) #Confirm that type is an array
streaks = str(streaks)
print("Number of streaks: " + streaks)
# Out:
# <class 'numpy.ndarray'>
# Number of streaks: 160

# %% [markdown]
# #### Q4: Pseudocode
# From what we've been taught, I was able to come up with this pseudocode
# - Collect 3 player profiles
#     - Name1 = input()
#
# - Collect variables and store the values of 10 different rolls for each palyer
#     - num = random.randint(1, 6)
#     - num1 = random.randint(1, 6)
#     - num2 = random.randint(1, 6)
#     - num3 = random.randint(1, 6)
#     - num4 = random.randint(1, 6)
#     - num5 = random.randint(1, 6)
#     - num6 = random.randint(1, 6)
#     - num7 = random.randint(1, 6)
#     - num8 = random.randint(1, 6)
#     - num9 = random.randint(1, 6)
# - Sum all 10 values
#    - rolls1 = num + num1+ num2 + num3 + num4 + num5 + num6 + num7 + num8 +num9
# - Repeat above for all 3 players
# - Create an if statement to check the max sum of all players rolls
#    - if rolls1>rolls2 and rolls1>rolls3:
#    -  print("Having "+rolls1+ ", " +Name1 + " has the highest rolls")
#    - elif rolls2>rolls3 and rolls2>rolls1:
#    -  print("Having "+rolls2+ ", " +Name2 + " has the highest rolls")
#    - elif rolls3>rolls1 and rolls3>rolls2:
#    -  print("Having "+rolls3+ ", " +Name3 + " has the highest rolls")

# %%
# Question 4 Solution:

import random

#Player 1
print("Hi Player1, Welcome to the rolling game. Please input your name?")
name1 = input()

print("Well, " + name1 + ", Please roll your die 10 times")
num = random.randint(1, 6)
num1 = random.randint(1, 6)
num2 = random.randint(1, 6)
num3 = random.randint(1, 6)
num4 = random.randint(1, 6)
num5 = random.randint(1, 6)
num6 = random.randint(1, 6)
num7 = random.randint(1, 6)
num8 = random.randint(1, 6)
num9 = random.randint(1, 6)

rolls1 = num + num1+ num2 + num3 + num4 + num5 + num6 + num7 + num8 +num9
rolls1 = str(rolls1)
num = str(num)
num1 = str(num1)
num2 = str(num2)
num3 = str(num3)
num4 = str(num4)
num5 = str(num5)
num6 = str(num6)
num7 = str(num7)
num8 = str(num8)
num9 = str(num9)
print("Your 10 rolls are: " +num+ ", " +num1+ ", "+num2+ ", " +num3+ ", " +num4+ ", "+num5+ ", " +num6+ ", " +num7+ ", "+num8+ ", " +num9+ ". Your total sum of rolls is "+rolls1)

#Player 2
print(" ")
print("Hi Player2, Welcome to the rolling game. Please input your name?")
name2 = input()

print("Well, " + name2 + ", Please roll your die 10 times")
num = random.randint(1, 6)
num1 = random.randint(1, 6)
num2 = random.randint(1, 6)
num3 = random.randint(1, 6)
num4 = random.randint(1, 6)
num5 = random.randint(1, 6)
num6 = random.randint(1, 6)
num7 = random.randint(1, 6)
num8 = random.randint(1, 6)
num9 = random.randint(1, 6)

rolls2 = num + num1+ num2 + num3 + num4 + num5 + num6 + num7 + num8 +num9
rolls2 = str(rolls2)
num = str(num)
num1 = str(num1)
num2 = str(num2)
num3 = str(num3)
num4 = str(num4)
num5 = str(num5)
num6 = str(num6)
num7 = str(num7)
num8 = str(num8)
num9 = str(num9)
print("Your 10 rolls are: " +num+ ", " +num1+ ", "+num2+ ", " +num3+ ", " +num4+ ", "+num5+ ", " +num6+ ", " +num7+ ", "+num8+ ", " +num9+ ". Your total sum of rolls is "+rolls2)

#Player 3
print(" ")
print("Hi Player3, Welcome to the rolling game. Please input your name?")
name3 = input()

print("Well, " + name3 + ", Please roll your die 10 times")
num = random.randint(1, 6)
num1 = random.randint(1, 6)
num2 = random.randint(1, 6)
num3 = random.randint(1, 6)
num4 = random.randint(1, 6)
num5 = random.randint(1, 6)
num6 = random.randint(1, 6)
num7 = random.randint(1, 6)
num8 = random.randint(1, 6)
num9 = random.randint(1, 6)

rolls3 = num + num1+ num2 + num3 + num4 + num5 + num6 + num7 + num8 +num9
rolls3 = str(rolls3)
num = str(num)
num1 = str(num1)
num2 = str(num2)
num3 = str(num3)
num4 = str(num4)
num5 = str(num5)
num6 = str(num6)
num7 = str(num7)
num8 = str(num8)
num9 = str(num9)
print("Your 10 rolls are: " +num+ ", " +num1+ ", "+num2+ ", " +num3+ ", " +num4+ ", "+num5+ ", " +num6+ ", " +num7+ ", "+num8+ ", " +num9+ ". Your total sum of rolls is "+rolls3)
print(" ")
print(" ")

if rolls1>rolls2 and rolls1>rolls3:
    print(name1+ " is the WINNER, having " +rolls1+ " as the highest sum of rolls.")
elif rolls2>rolls3 and rolls2>rolls1:
    print(name2+ " is the WINNER, having " +rolls2+ " as the highest sum of rolls.")
elif rolls3>rolls1 and rolls3>rolls2:
    print(name3+ " is the WINNER, having " +rolls3+ " as the highest sum of rolls.")
else:
    print("It's a tie.")
# Out:
# Hi Player1, Welcome to the rolling game. Please input your name?
# K
# Well, K, Please roll your die 10 times
# Your 10 rolls are: 6, 3, 4, 1, 4, 5, 6, 3, 4, 5. Your total sum of rolls is 41
#
# Hi Player2, Welcome to the rolling game. Please input your name?
# B
# Well, B, Please roll your die 10 times
# Your 10 rolls are: 2, 4, 5, 6, 1, 4, 3, 5, 2, 6. Your total sum of rolls is 38
#
# Hi Player3, Welcome to the rolling game. Please input your name?
# U
# Well, U, Please roll your die 10 times
# Your 10 rolls are: 1, 1, 1, 5, 1, 2, 3, 1, 1, 1. Your total sum of rolls is 17
#
#
# K is the WINNER, having 41 as the highest sum of rolls.
